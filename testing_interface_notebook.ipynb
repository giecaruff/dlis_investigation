# %%
# %matplotlib widget
import numpy as np
from dlisio_r import DLISAccess

dlis_mng = DLISAccess(r"D:\santos_from_bruna\1-BRSA-369A-RJS\Perfis\DLIS\Original\1-brsa-369a-rjs_raw2_8.dlis")

# %%
dlis_mng.get_data()
# Out:
# {}
