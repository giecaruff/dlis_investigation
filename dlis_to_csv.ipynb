# %%
# !pip install dlisio==0.3.7
# !pip install lasio

# %%
from dlisio import dlis
import pandas as pd
import numpy as np

def dlis_access(filepath, depth_track = 0, logical_file = 0, null=-999.25):
    with dlis.load(filepath) as files:
        frame_all = {} # dicionario vazio (armazenar os logical files)
        ii = 0 # indexador (nome de acesso) dos logical files
        for f in files:
            for frame in f.frames:
                curves = frame.curves()

                channel_data = {
                        "curves_name": [],
                        "longs": [],
                        "unit": [],
                        "curves_L": [],
                        "las_units": [],
                        "las_longs": [],
                    }

                for channel in frame.channels:
                    channel_data["curves_name"].append(channel.name)
                    channel_data["longs"].append(channel.long_name)
                    channel_data["unit"].append(channel.units)
                    curves = channel.curves()
                    channel_data["curves_L"].append(curves)
                    
                print(channel_data["curves_name"])
                print(channel_data["curves_L"][depth_track])
                print()
                
                A = process_curve_info(channel_data)
                
                DATA = {}
                for i in range(len(A['curves_name'])):
                    DATA[A['curves_name'][i]] = {}
                    DATA[A['curves_name'][i]]['curve'] = A['curves_L'][i]
                    DATA[A['curves_name'][i]]['unit'] = A['unit'][i]

                frame_all[ii] = DATA
            ii += 1
            
    return frame_all[logical_file]

# %%
DATA = dlis_access(
    r'C:\Users\isabela\Desktop\1-BRSA-1007-RJS\Perfis_Digitais\DLIS\1-brsa-1007-rjs_8_quad.dlis',
    logical_file = 1, null=-888) # , null=-999.25
# Out:
# ['TDEP', 'BS', 'CS', 'MINM', 'TENS', 'DLIM', 'DPHD', 'DPHI', 'DPHS', 'DRHO', 'PE', 'RHOB', 'AHV', 'AHVT', 'BHV', 'BHVT', 'CALI', 'DCAL', 'GR', 'FDSN', 'NDSN', 'NLIM', 'NPHD', 'NPHI', 'NPHS', 'NRAT', 'TEM2', 'FBA', 'FDE', 'FHI', 'FLI', 'FLO', 'FPK', 'NBA', 'NDE', 'NHI', 'NLI', 'NLO', 'NPK', 'RT90', 'RT60', 'RT30', 'RT20', 'RT10', 'RT06', 'DT', 'ITT']
# [5055.60009766 5055.50009765 5055.40009765 ... 4903.10009538 4903.00009538
#  4902.90009538]
#
# Processing TDEP
# Completed TDEP
# Processing BS
# Completed BS
# Processing CS
# Completed CS
# Processing MINM
# Completed MINM
# Processing TENS
# Completed TENS
# Processing DLIM
# Completed DLIM
# Processing DPHD
# Completed DPHD
# Processing DPHI
# Completed DPHI
# Processing DPHS
# Completed DPHS
# Processing DRHO
# Completed DRHO
# Processing PE
# Completed PE
# Processing RHOB
# Completed RHOB
# Processing AHV
# Completed AHV
# Processing AHVT
# Completed AHVT
# Processing BHV
# Completed BHV
# Processing BHVT
# Completed BHVT
# Processing CALI
# Completed CALI
# Processing DCAL
# Completed DCAL
# Processing GR
# Completed GR
# Processing FDSN
# Completed FDSN
# Processing NDSN
# Completed NDSN
# Processing NLIM
# Completed NLIM
# Processing NPHD
# Completed NPHD
# Processing NPHI
# Completed NPHI
# Processing NPHS
# Completed NPHS
# Processing NRAT
# Completed NRAT
# Processing TEM2
# Completed TEM2
# Processing FBA
# Completed FBA
# Processing FDE
# Completed FDE
# Processing FHI
# Completed FHI
# Processing FLI
# Completed FLI
# Processing FLO
# Completed FLO
# Processing FPK
# Completed FPK
# Processing NBA
# Completed NBA
# Processing NDE
# Completed NDE
# Processing NHI
# Completed NHI
# Processing NLI
# Completed NLI
# Processing NLO
# Completed NLO
# Processing NPK
# Completed NPK
# Processing RT90
# Completed RT90
# Processing RT60
# Completed RT60
# Processing RT30
# Completed RT30
# Processing RT20
# Completed RT20
# Processing RT10
# Completed RT10
# Processing RT06
# Completed RT06
# Processing DT
# Completed DT
# Processing ITT
# Completed ITT
# If these are different lengths, something is wrong:
# 47
# 47
# ['TDEP', 'BS', 'CS', 'MINM', 'TENS', 'DLIM', 'DPHD', 'DPHI', 'DPHS', 'DRHO', 'PE', 'RHOB', 'AHV', 'AHVT', 'BHV', 'BHVT', 'CALI', 'DCAL', 'GR', 'FDSN', 'NDSN', 'NLIM', 'NPHD', 'NPHI', 'NPHS', 'NRAT', 'TEM2', 'FBA', 'FDE', 'FHI', 'FLI', 'FLO', 'FPK', 'NBA', 'NDE', 'NHI', 'NLI', 'NLO', 'NPK', 'RT90', 'RT60', 'RT30', 'RT20', 'RT10', 'RT06', 'DT', 'ITT']
# [5600.89990234 5600.79990234 5600.69990234 ... 4840.99989102 4840.89989102
#  4840.79989102]
#
# Processing TDEP
# Completed TDEP
# Processing BS
# Completed BS
# Processing CS
# Completed CS
# Processing MINM
# Completed MINM
# Processing TENS
# Completed TENS
# Processing DLIM
# Completed DLIM
# Processing DPHD
# Completed DPHD
# Processing DPHI
# Completed DPHI
# Processing DPHS
# Completed DPHS
# Processing DRHO
# Completed DRHO
# Processing PE
# Completed PE
# Processing RHOB
# Completed RHOB
# Processing AHV
# Completed AHV
# Processing AHVT
# Completed AHVT
# Processing BHV
# Completed BHV
# Processing BHVT
# Completed BHVT
# Processing CALI
# Completed CALI
# Processing DCAL
# Completed DCAL
# Processing GR
# Completed GR
# Processing FDSN
# Completed FDSN
# Processing NDSN
# Completed NDSN
# Processing NLIM
# Completed NLIM
# Processing NPHD
# Completed NPHD
# Processing NPHI
# Completed NPHI
# Processing NPHS
# Completed NPHS
# Processing NRAT
# Completed NRAT
# Processing TEM2
# Completed TEM2
# Processing FBA
# Completed FBA
# Processing FDE
# Completed FDE
# Processing FHI
# Completed FHI
# Processing FLI
# Completed FLI
# Processing FLO
# Completed FLO
# Processing FPK
# Completed FPK
# Processing NBA
# Completed NBA
# Processing NDE
# Completed NDE
# Processing NHI
# Completed NHI
# Processing NLI
# Completed NLI
# Processing NLO
# Completed NLO
# Processing NPK
# Completed NPK
# Processing RT90
# Completed RT90
# Processing RT60
# Completed RT60
# Processing RT30
# Completed RT30
# Processing RT20
# Completed RT20
# Processing RT10
# Completed RT10
# Processing RT06
# Completed RT06
# Processing DT
# Completed DT
# Processing ITT
# Completed ITT
# If these are different lengths, something is wrong:
# 47
# 47
# ['TDEP', 'BS', 'CALI', 'CS', 'DCAL', 'DLIM', 'DPHD', 'DPHI', 'DPHS', 'DRHO', 'FBA', 'FDE', 'FDSN', 'FHI', 'FLI', 'FLO', 'FPK', 'GR', 'MINM', 'NBA', 'NDE', 'NDSN', 'NHI', 'NLI', 'NLIM', 'NLO', 'NPHD', 'NPHI', 'NPHS', 'NPK', 'NRAT', 'PE', 'RHOB', 'TEM2', 'TENS']
# [5600.82519531 5600.80019531 5600.77519531 ... 4840.80018399 4840.77518399
#  4840.75018399]
#
# Processing TDEP
# Completed TDEP
# Processing BS
# Completed BS
# Processing CALI
# Completed CALI
# Processing CS
# Completed CS
# Processing DCAL
# Completed DCAL
# Processing DLIM
# Completed DLIM
# Processing DPHD
# Completed DPHD
# Processing DPHI
# Completed DPHI
# Processing DPHS
# Completed DPHS
# Processing DRHO
# Completed DRHO
# Processing FBA
# Completed FBA
# Processing FDE
# Completed FDE
# Processing FDSN
# Completed FDSN
# Processing FHI
# Completed FHI
# Processing FLI
# Completed FLI
# Processing FLO
# Completed FLO
# Processing FPK
# Completed FPK
# Processing GR
# Completed GR
# Processing MINM
# Completed MINM
# Processing NBA
# Completed NBA
# Processing NDE
# Completed NDE
# Processing NDSN
# Completed NDSN
# Processing NHI
# Completed NHI
# Processing NLI
# Completed NLI
# Processing NLIM
# Completed NLIM
# Processing NLO
# Completed NLO
# Processing NPHD
# Completed NPHD
# Processing NPHI
# Completed NPHI
# Processing NPHS
# Completed NPHS
# Processing NPK
# Completed NPK
# Processing NRAT
# Completed NRAT
# Processing PE
# Completed PE
# Processing RHOB
# Completed RHOB
# Processing TEM2
# Completed TEM2
# Processing TENS
# Completed TENS
# If these are different lengths, something is wrong:
# 35
# 35
# {0: {'TDEP': {'curve': array([5055.60009766, 5055.50009765, 5055.40009765, ..., 4903.10009538,
#        4903.00009538, 4902.90009538]), 'unit': 'm'}, 'BS': {'curve': array([-999.25,    8.5 ,    8.5 , ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'in'}, 'CS': {'curve': array([-999.25     ,    0.       ,    2.6999946, ..., -999.25     ,
#        -999.25     , -999.25     ], dtype=float32), 'unit': 'mpm'}, 'MINM': {'curve': array([-999,    0,    0, ..., -999, -999, -999]), 'unit': 'NONE'}, 'TENS': {'curve': array([-999.25  , 5852.645 , 6143.4854, ..., -999.25  , -999.25  ,
#        -999.25  ], dtype=float32), 'unit': 'lbs'}, 'DLIM': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DPHD': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DPHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DPHS': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DRHO': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'g/cc'}, 'PE': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'b/e'}, 'RHOB': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'g/cc'}, 'AHV': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'm3'}, 'AHVT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'm3'}, 'BHV': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'm3'}, 'BHVT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'm3'}, 'CALI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'in'}, 'DCAL': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'in'}, 'GR': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'gapi'}, 'FDSN': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NDSN': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NLIM': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'NPHD': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'NPHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': ''}, 'NPHS': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'NRAT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'NONE'}, 'TEM2': {'curve': array([ 201.70563,  201.73412,  201.94304, ..., -999.25   , -999.25   ,
#        -999.25   ], dtype=float32), 'unit': 'degF'}, 'FBA': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FDE': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FLI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FLO': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FPK': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NBA': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NDE': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NLI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NLO': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NPK': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'RT90': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT60': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT30': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT20': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT10': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT06': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'DT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'uspf'}, 'ITT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ms'}}, 1: {'TDEP': {'curve': array([5600.89990234, 5600.79990234, 5600.69990234, ..., 4840.99989102,
#        4840.89989102, 4840.79989102]), 'unit': 'm'}, 'BS': {'curve': array([-999.25,    8.5 ,    8.5 , ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'in'}, 'CS': {'curve': array([-999.25     ,    2.999994 ,    3.2999935, ..., -999.25     ,
#        -999.25     , -999.25     ], dtype=float32), 'unit': 'mpm'}, 'MINM': {'curve': array([-999,    0,    0, ..., -999, -999, -999]), 'unit': 'NONE'}, 'TENS': {'curve': array([-999.25 , 6046.069, 6535.67 , ..., -999.25 , -999.25 , -999.25 ],
#       dtype=float32), 'unit': 'lbs'}, 'DLIM': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DPHD': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DPHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DPHS': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DRHO': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'g/cc'}, 'PE': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'b/e'}, 'RHOB': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'g/cc'}, 'AHV': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'm3'}, 'AHVT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'm3'}, 'BHV': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'm3'}, 'BHVT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'm3'}, 'CALI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'in'}, 'DCAL': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'in'}, 'GR': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'gapi'}, 'FDSN': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NDSN': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NLIM': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'NPHD': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'NPHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': ''}, 'NPHS': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'NRAT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'NONE'}, 'TEM2': {'curve': array([ 244.79897,  244.97787,  244.74928, ..., -999.25   , -999.25   ,
#        -999.25   ], dtype=float32), 'unit': 'degF'}, 'FBA': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FDE': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FLI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FLO': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FPK': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NBA': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NDE': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NLI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NLO': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NPK': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'RT90': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT60': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT30': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT20': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT10': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'RT06': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ohmm'}, 'DT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'uspf'}, 'ITT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'ms'}}, 2: {'TDEP': {'curve': array([5600.82519531, 5600.80019531, 5600.77519531, ..., 4840.80018399,
#        4840.77518399, 4840.75018399]), 'unit': 'm'}, 'BS': {'curve': array([-999.25,    8.5 ,    8.5 , ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'in'}, 'CALI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'in'}, 'CS': {'curve': array([-999.25    ,    2.999994,    2.999994, ..., -999.25    ,
#        -999.25    , -999.25    ], dtype=float32), 'unit': 'mpm'}, 'DCAL': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'in'}, 'DLIM': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DPHD': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DPHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DPHS': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'DRHO': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'g/cc'}, 'FBA': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FDE': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FDSN': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FLI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FLO': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'FPK': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'GR': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'gapi'}, 'MINM': {'curve': array([-999,    0,    0, ..., -999, -999, -999]), 'unit': 'NONE'}, 'NBA': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NDE': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NDSN': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NLI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NLIM': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'NLO': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NPHD': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'NPHI': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': ''}, 'NPHS': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'decp'}, 'NPK': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'cps'}, 'NRAT': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'NONE'}, 'PE': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'NONE'}, 'RHOB': {'curve': array([-999.25, -999.25, -999.25, ..., -999.25, -999.25, -999.25],
#       dtype=float32), 'unit': 'g/cc'}, 'TEM2': {'curve': array([ 244.79897,  244.97787,  244.73935, ..., -999.25   , -999.25   ,
#        -999.25   ], dtype=float32), 'unit': 'degF'}, 'TENS': {'curve': array([-999.25  , 6046.069 , 6086.3276, ..., -999.25  , -999.25  ,
#        -999.25  ], dtype=float32), 'unit': 'lbs'}}}

# %%
#tosave = ['TDEP', 'BS', 'CS', 'MINM', 'TENS', 'DLIM', 'DPHD', 'DPHI', 'DPHS', 'DRHO', 'PE', 'RHOB', 'AHV', 'AHVT', 'BHV', 'BHVT', 'CALI', 'DCAL', 'GR', 'FDSN', 'NDSN', 'NLIM', 'NPHD', 'NPHI', 'NPHS', 'NRAT', 'TEM2', 'FBA', 'FDE', 'FHI', 'FLI', 'FLO', 'FPK', 'NBA', 'NDE', 'NHI', 'NLI', 'NLO', 'NPK', 'RT90', 'RT60', 'RT30', 'RT20', 'RT10', 'RT06', 'DT', 'ITT']
tosave = ['TDEP', 'BS', 'RHOB', 'GR','RT90','DT']


all_data = []
for m in tosave:  
    column = [m] + [DATA[m]['unit']] + list(DATA[m]['curve'])
    all_data.append(column)
    

DF = pd.DataFrame(all_data).T
new_header = DF.iloc[0]
DF = DF[1:]
DF.columns = new_header
DF.to_csv("C:\\Users\\isabela\\Desktop\\1-BRSA-1007-RJS\\Perfis_Digitais\\LAS\\1-brsa-1007-rjs_8_quad.csv", index=False)
